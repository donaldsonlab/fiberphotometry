# %%
import pandas as pd
fpho_df=pd.read_csv('my_file_name_Summary.csv')
fpho_df
# Out:
#           animalID        date                  description     fTimeIso  \
# 0       3737, 3738  2020-11-22  my experiment was about ...     7.523744
# 1       3737, 3738  2020-11-22  my experiment was about ...     7.548736
# 2       3737, 3738  2020-11-22  my experiment was about ...     7.573728
# 3       3737, 3738  2020-11-22  my experiment was about ...     7.598720
# 4       3737, 3738  2020-11-22  my experiment was about ...     7.623712
# ...            ...         ...                          ...          ...
# 153234  3737, 3738  2020-11-22  my experiment was about ...  3837.741152
# 153235  3737, 3738  2020-11-22  my experiment was about ...  3837.766176
# 153236  3737, 3738  2020-11-22  my experiment was about ...  3837.791136
# 153237  3737, 3738  2020-11-22  my experiment was about ...  3837.816160
# 153238  3737, 3738  2020-11-22  my experiment was about ...  3837.841120
#
#            fTimeRed   fTimeGreen  f1GreenGreen  f1GreenIso  f1RedRed  \
# ...

# %%
object_columns = fpho_df.select_dtypes(include=['bool']).columns
    
print(object_columns)
# Out:
# Index(['nonsocial', 'seperate', 'together', 'active interaction',
#        'one sided interaction', 'passive interaction'],
#       dtype='object')

# %%
import correlation_setup as cs

rows=[0]
behs= ['together', 'seperate']
channels= ['GreenGreen']
print(cs.behavior_specific_pearsons(fpho_df, rows, channels, behs))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-8-4be5a0af8d75> in <module>
#       4 behs= ['together', 'seperate']
#       5 channels= ['GreenGreen']
# ----> 6 print(cs.behavior_specific_pearsons(fpho_df, rows, channels, behs))
#
# ~\Documents\GitHub\fiberphotometry\Python\correlation_setup.py in behavior_specific_pearsons(df, rows, channels, behs)
#      27         results[channel]={}
#      28         for row in rows:
# ---> 29             print(df.loc[row, 'fTimeGreen'])
#      30             print(df.loc[row, 'Behavior Time'])
#      31             fTimeBehIdx = np.searchsorted(df.loc[row, 'fTimeGreen'], df.loc[row, 'Behavior Time'])
#
# <__array_function__ internals> in searchsorted(*args, **kwargs)
#
# ~\Anaconda3\lib\site-packages\numpy\core\fromnumeric.py in searchsorted(a, v, side, sorter)
#    1339
#    1340     """
# ...
